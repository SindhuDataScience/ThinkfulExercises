# %%
import numpy as np
import pandas as pd

# %%
students_performance = pd.DataFrame()
fields = ['gender', 'race/ethnicity','math score','reading score','writing score']
students_performance = pd.read_csv(r"C:\Users\Niranjan\Desktop\Data Science\Python\exercise\StudentsPerformance.csv", usecols=fields, nrows=10)
print(students_performance)
# Out:
#    gender race/ethnicity  math score  reading score  writing score
# 0  female        group B          72             72             74
# 1  female        group C          69             90             88
# 2  female        group B          90             95             93
# 3    male        group A          47             57             44
# 4    male        group C          76             78             75
# 5  female        group B          71             83             78
# 6  female        group B          88             95             92
# 7    male        group B          40             43             39
# 8    male        group D          64             64             67
# 9  female        group B          38             60             50

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(students_performance['math score'])
plt.show()

# %% [markdown]
# The above plot shows how the scores are distuributed for the students. x-axis represents the number of students and y-axis is the scores ranging from 0 to 100.

# %%
plt.scatter(students_performance['writing score'],students_performance['reading score'])
plt.show()

# %% [markdown]
# There is a high positive correlation between Writing scores and reading scores. As one increases the other parameter is increasing.

# %%
plt.boxplot(students_performance['math score'])
plt.show()

# %% [markdown]
# Looking at the above box plot, it is evident that most of the students scored inbetween 50 and 70. There are a couple of outliers (one at 0 and one at 20)

# %%
plt.hist(students_performance['math score'],bins=50)
df.plot(kind=hist)

# %% [markdown]
# Peak of the histogram is between 55-60. This represents that the highest number of students (8 students) scored in this range. Majority of them scored between 40 and 80 in Math.
