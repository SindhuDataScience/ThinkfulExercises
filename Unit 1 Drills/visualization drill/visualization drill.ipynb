# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
DSWeatherData = pd.read_csv(r"C:\Users\Niranjan\Desktop\Data Science\git\ThinkfulExercises\Unit 1 Drills\visualization drill\weatherAUS.csv")
DSWeatherData.tail(10)
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 142183  6/15/2017    Uluru      2.6     22.5       0.0          NaN       NaN
# 142184  6/16/2017    Uluru      5.2     24.3       0.0          NaN       NaN
# 142185  6/17/2017    Uluru      6.4     23.4       0.0          NaN       NaN
# 142186  6/18/2017    Uluru      8.0     20.7       0.0          NaN       NaN
# 142187  6/19/2017    Uluru      7.4     20.6       0.0          NaN       NaN
# 142188  6/20/2017    Uluru      3.5     21.8       0.0          NaN       NaN
# 142189  6/21/2017    Uluru      2.8     23.4       0.0          NaN       NaN
# 142190  6/22/2017    Uluru      3.6     25.3       0.0          NaN       NaN
# 142191  6/23/2017    Uluru      5.4     26.9       0.0          NaN       NaN
# 142192  6/24/2017    Uluru      7.8     27.0       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# ...

# %%
DSWeatherData.Location.nunique()
# Out:
# 49

# %%
DSWeatherData.Location.unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
#Choose one variable and plot that variable four different ways.
sns.set(color_codes=True)
DSWeatherData['MinTemp'] = DSWeatherData['MinTemp'].fillna(0)
DSWeatherData['MaxTemp'] = DSWeatherData['MaxTemp'].fillna(0)
plt.figure(figsize=(15,8))
sns.distplot(DSWeatherData.MinTemp, bins=100, hist=False); #rug=True,

# %%
#kernel density estimate
sns.kdeplot(DSWeatherData.MinTemp)
sns.kdeplot(DSWeatherData.MinTemp, bw=.5, label="bw: 0.5")
sns.kdeplot(DSWeatherData.MinTemp, bw=2, label="bw: 2")
plt.legend();

# %%
sns.distplot(DSWeatherData.MinTemp, kde=False, fit=stats.gamma);

# %%
sns.rugplot(DSWeatherData.MinTemp, color=".4", linewidth=1);

# %%
#Choose two continuous variables, and plot them three different ways.
#Choosing MinTemp and MaxTemp
sns.jointplot(x=DSWeatherData.MinTemp, y=DSWeatherData.MaxTemp, color='red', kind="hex");

# %%
sns.kdeplot(DSWeatherData.MinTemp.head(100), DSWeatherData.MaxTemp.head(100))
sns.rugplot(DSWeatherData.MinTemp.head(100), color="g")
sns.rugplot(DSWeatherData.MaxTemp.head(100), vertical=True);

# %%
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(DSWeatherData.MinTemp.head(100), DSWeatherData.MaxTemp.head(100), cmap=cmap, n_levels=60, shade=True);

# %%
#Choose one continuous variable and one categorical variable, and plot them six different ways.
#Choosing Location and WindGustSpeed
DSWeatherData.dropna(subset=['WindGustSpeed'])
DSWeatherData.count()
# Out:
# Date             142193
# Location         142193
# MinTemp          142193
# MaxTemp          142193
# Rainfall         140787
# Evaporation       81350
# Sunshine          74377
# WindGustDir      132863
# WindGustSpeed    132923
# WindDir9am       132180
# WindDir3pm       138415
# WindSpeed9am     140845
# WindSpeed3pm     139563
# Humidity9am      140419
# Humidity3pm      138583
# Pressure9am      128179
# Pressure3pm      128212
# Cloud9am          88536
# Cloud3pm          85099
# Temp9am          141289
# Temp3pm          139467
# RainToday        140787
# RISK_MM          142193
# RainTomorrow     142193
# dtype: int64

# %%
df1 = DSWeatherData[DSWeatherData.Location.isin(['Albury','BadgerysCreek', 'Cobar'])]
df1.dropna(subset=['Location','WindGustSpeed'])
df1.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   12/1/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1   12/2/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2   12/3/2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3   12/4/2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4   12/5/2008   Albury     17.5     32.3       1.0          NaN       NaN
# 5   12/6/2008   Albury     14.6     29.7       0.2          NaN       NaN
# 6   12/7/2008   Albury     14.3     25.0       0.0          NaN       NaN
# 7   12/8/2008   Albury      7.7     26.7       0.0          NaN       NaN
# 8   12/9/2008   Albury      9.7     31.9       0.0          NaN       NaN
# 9  12/10/2008   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# ...

# %%
#Categorical plot
#sns.catplot(x=df1.Location, y=df1.WindGustSpeed);
sns.swarmplot(x=df1.Location, y=df1.WindGustSpeed, color="k", size=3)

# %%
sns.catplot(x="Location", y="WindGustSpeed", kind="violin", data=df1)

# %%
sns.violinplot(x=df1.Location, y=df1.WindGustSpeed);

# %%
sns.stripplot(x=df1.Location, y=df1.WindGustSpeed)

# %%
ax = sns.boxplot(x="Location", y="WindGustSpeed", data=df1)
#ax = sns.stripplot(x="Location", y="WindGustSpeed", data=df1, jitter=True, color=".3")

# %%
sns.catplot(x="Location", y="WindGustSpeed", kind="bar", data=df1);

# %%
sns.catplot(x="Location", y="WindGustSpeed",  kind="point", data=df1);
